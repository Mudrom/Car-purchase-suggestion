# %%
c

# %%
a=['张','李','王']
b=['三','四','二']
d=['三','四','二']
c=zip(a,b,d)
next(c)
next(c)
# Out:
# ('李', '四', '四')

# %%
for i in c:
    print("".join(i))

# %%
a=[1,2,3]
b=a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
a is b
# Out:
# True

# %%
# !pip install jieba

# %%
import jieba
a=jieba.lcut('中华人民共和国是一个伟大的祖国')
print(a)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\LIN\AppData\Local\Temp\jieba.cache
# Loading model cost 6.339 seconds.
# Prefix dict has been built successfully.
# ['中华人民共和国', '是', '一个', '伟大', '的', '祖国']

# %%
f=open('E:\\python培训\\练习打开.txt','r')
p=f.readlines()
print(p)
f.close()
# Out:
# ['练习题\n', '一、单项选择题\n', '1．下列各项中，导致负债总额变化的是（D）。\n', 'A.发放股票股利B.用现金购买商品\n', 'C.用盈余公积转增资本D.赊购商品\n', '2．下列各项中，不属于负债类别的是（）B。\n', 'A.应交税费B.预付账款\n', 'C.应付债券D.长期借款\n', '3．某企业以一张期限为8个月的商业承兑汇票支付货款，票面价值为100万元，票面年利率为4.5％。该票据到期时，企业应支付的金额为（C）。\n', 'A.100B.101.5\n', 'C.103D.104.5\n', '4．预收货款业务不多的企业，可以不设置“预收账款”科目，其所发生的预收货款，可以\n', '通过（B）核算。\n', 'A.“应收账款”科目借方B.“应收账款”科目贷方\n', 'C.“应付账款”科目借方D.“应付账款”科目贷方\n', '5．非流动负债又称为（A）。\n', 'A.长期负债B.长期借款\n', 'C.应付账款D.应付债券\n', '6．投入者投入资本时，贷记的会计科目是（D）。\n', 'A.银行存款B.无形资产\n', 'C.固定资产D.实收资本\n', '7．企业将当年实现的净利润转入“利润分配——未分配利润”账户时，借记（D）科目。\n', 'A.银行存款B.资本公积\n', 'C.利润分配D.本年利润\n', '8．某股份有限公司溢价发行债券，目前市场利率为8%，该债券的票面利率不可能是（D）。\n', 'A.12%B.10%\n', 'C.8%D.6%\n', '9．以下各项中，会引起留存收益总额发生增减变化的是（D）。\n', '留存收益=盈余公积+利润分配\n', '未分配利润来源于两个账户：本年利润和利润分配\n', 'A.用税后利润补亏\n', '借：本年利润\n', '\t贷：利润分配——未分配利润\n', 'B.用盈余公积补亏（）\n', '借：盈余公积\n', '贷：利润分配——未分配利润\n', 'C.用资本公积转增资本\n', '借：资本公积\n', '\t贷：实收资本\n', '\t\n', 'D.用盈余公积转增资本\n', '借： 盈余公积\n', '\t贷：实收资本\n', '\t\n', '\n', '二、多项选择题\n', '1．下列经济业务或事项中，属于负债的有（AD）。\
# ...

# %%
f=open('E:\\python培训\\练习打开.txt','r')
p=f.readline()
print(p)
f.close()
# Out:
# 练习题

# %%
f=open('E:\\python培训\\练习打开.txt','r')
p=f.read()
print(p)
f.close()
# Out:
# 练习题
# 一、单项选择题
# 1．下列各项中，导致负债总额变化的是（D）。
# A.发放股票股利B.用现金购买商品
# C.用盈余公积转增资本D.赊购商品
# 2．下列各项中，不属于负债类别的是（）B。
# A.应交税费B.预付账款
# C.应付债券D.长期借款
# 3．某企业以一张期限为8个月的商业承兑汇票支付货款，票面价值为100万元，票面年利率为4.5％。该票据到期时，企业应支付的金额为（C）。
# A.100B.101.5
# C.103D.104.5
# 4．预收货款业务不多的企业，可以不设置“预收账款”科目，其所发生的预收货款，可以
# 通过（B）核算。
# A.“应收账款”科目借方B.“应收账款”科目贷方
# C.“应付账款”科目借方D.“应付账款”科目贷方
# 5．非流动负债又称为（A）。
# A.长期负债B.长期借款
# C.应付账款D.应付债券
# 6．投入者投入资本时，贷记的会计科目是（D）。
# A.银行存款B.无形资产
# C.固定资产D.实收资本
# 7．企业将当年实现的净利润转入“利润分配——未分配利润”账户时，借记（D）科目。
# A.银行存款B.资本公积
# C.利润分配D.本年利润
# 8．某股份有限公司溢价发行债券，目前市场利率为8%，该债券的票面利率不可能是（D）。
# A.12%B.10%
# C.8%D.6%
# 9．以下各项中，会引起留存收益总额发生增减变化的是（D）。
# 留存收益=盈余公积+利润分配
# 未分配利润来源于两个账户：本年利润和利润分配
# A.用税后利润补亏
# 借：本年利润
# 	贷：利润分配——未分配利润
# B.用盈余公积补亏（）
# 借：盈余公积
# 贷：利润分配——未分配利润
# C.用资本公积转增资本
# 借：资本公积
# 	贷：实收资本
#
# D.用盈余公积转增资本
# 借： 盈余公积
# 	贷：实收资本
#
#
# 二、多项选择题
# 1．下列经济业务或事项中，属于负债的有（AD）。
# A.应付职工薪酬B.预付账款
# C.贷款计划D.预收账款
# 2．“应付债券”账户的贷方反映的内容有(BC)。
# A.债券发行时产生的债券溢价B.债券发行时债券的本金
# C.到期一次还本付息情形下期末计提的应计债券利息D.债券的发行费用
# ...

# %%
txtf = 'E:\\python培训\\data.txt'
#新建⼀个data.txt文件， 使用追加方式（a+），编码采用utf-8

# %%
f = open(txtf, 'a+', encoding='utf-8')

# %%
#采集到的文本数据
content = '采集到的文本数据'

# %%
#将content写入到data.txt中
f.write(content)
# Out:
# 8

# %%
#关闭f
f.close()

# %%
# !pip install chardet

# %%
import chardet
f=open('E:\\python培训\\练习打开.txt','rb')

# %%
s=f.read()
d=chardet.detect(s)
f.close()

# %%
print(d)
# Out:
# {'encoding': 'GB2312', 'confidence': 0.99, 'language': 'Chinese'}

# %%
f=open('E:\\python培训\\练习打开.txt','r',encoding='gbk')
p=f.readlines()
print(p)
f.close()
# Out:
# ['练习题\n', '一、单项选择题\n', '1．下列各项中，导致负债总额变化的是（D）。\n', 'A.发放股票股利B.用现金购买商品\n', 'C.用盈余公积转增资本D.赊购商品\n', '2．下列各项中，不属于负债类别的是（）B。\n', 'A.应交税费B.预付账款\n', 'C.应付债券D.长期借款\n', '3．某企业以一张期限为8个月的商业承兑汇票支付货款，票面价值为100万元，票面年利率为4.5％。该票据到期时，企业应支付的金额为（C）。\n', 'A.100B.101.5\n', 'C.103D.104.5\n', '4．预收货款业务不多的企业，可以不设置“预收账款”科目，其所发生的预收货款，可以\n', '通过（B）核算。\n', 'A.“应收账款”科目借方B.“应收账款”科目贷方\n', 'C.“应付账款”科目借方D.“应付账款”科目贷方\n', '5．非流动负债又称为（A）。\n', 'A.长期负债B.长期借款\n', 'C.应付账款D.应付债券\n', '6．投入者投入资本时，贷记的会计科目是（D）。\n', 'A.银行存款B.无形资产\n', 'C.固定资产D.实收资本\n', '7．企业将当年实现的净利润转入“利润分配——未分配利润”账户时，借记（D）科目。\n', 'A.银行存款B.资本公积\n', 'C.利润分配D.本年利润\n', '8．某股份有限公司溢价发行债券，目前市场利率为8%，该债券的票面利率不可能是（D）。\n', 'A.12%B.10%\n', 'C.8%D.6%\n', '9．以下各项中，会引起留存收益总额发生增减变化的是（D）。\n', '留存收益=盈余公积+利润分配\n', '未分配利润来源于两个账户：本年利润和利润分配\n', 'A.用税后利润补亏\n', '借：本年利润\n', '\t贷：利润分配——未分配利润\n', 'B.用盈余公积补亏（）\n', '借：盈余公积\n', '贷：利润分配——未分配利润\n', 'C.用资本公积转增资本\n', '借：资本公积\n', '\t贷：实收资本\n', '\t\n', 'D.用盈余公积转增资本\n', '借： 盈余公积\n', '\t贷：实收资本\n', '\t\n', '\n', '二、多项选择题\n', '1．下列经济业务或事项中，属于负债的有（AD）。\
# ...

# %%
with open('E:\\python培训\\练习打开.txt','rb') as f:
    s=f.read()
    d=chardet.detect(s)
    e=d['encoding']
s2=s.decode('gbk')
s
# Out:
# b'\xc1\xb7\xcf\xb0\xcc\xe2\r\n\xd2\xbb\xa1\xa2\xb5\xa5\xcf\xee\xd1\xa1\xd4\xf1\xcc\xe2\r\n1\xa3\xae\xcf\xc2\xc1\xd0\xb8\xf7\xcf\xee\xd6\xd0\xa3\xac\xb5\xbc\xd6\xc2\xb8\xba\xd5\xae\xd7\xdc\xb6\xee\xb1\xe4\xbb\xaf\xb5\xc4\xca\xc7\xa3\xa8D\xa3\xa9\xa1\xa3\r\nA.\xb7\xa2\xb7\xc5\xb9\xc9\xc6\xb1\xb9\xc9\xc0\xfbB.\xd3\xc3\xcf\xd6\xbd\xf0\xb9\xba\xc2\xf2\xc9\xcc\xc6\xb7\r\nC.\xd3\xc3\xd3\xaf\xd3\xe0\xb9\xab\xbb\xfd\xd7\xaa\xd4\xf6\xd7\xca\xb1\xbeD.\xc9\xde\xb9\xba\xc9\xcc\xc6\xb7\r\n2\xa3\xae\xcf\xc2\xc1\xd0\xb8\xf7\xcf\xee\xd6\xd0\xa3\xac\xb2\xbb\xca\xf4\xd3\xda\xb8\xba\xd5\xae\xc0\xe0\xb1\xf0\xb5\xc4\xca\xc7\xa3\xa8\xa3\xa9B\xa1\xa3\r\nA.\xd3\xa6\xbd\xbb\xcb\xb0\xb7\xd1B.\xd4\xa4\xb8\xb6\xd5\xcb\xbf\xee\r\nC.\xd3\xa6\xb8\xb6\xd5\xae\xc8\xafD.\xb3\xa4\xc6\xda\xbd\xe8\xbf\xee\r\n3\xa3\xae\xc4\xb3\xc6\xf3\xd2\xb5\xd2\xd4\xd2\xbb\xd5\xc5\xc6\xda\xcf\xde\xce\xaa8\xb8\xf6\xd4\xc2\xb5\xc4\xc9\xcc\xd2\xb5\xb3\xd0\xb6\xd2\xbb\xe3\xc6\xb1\xd6\xa7\xb8\xb6\xbb\xf5\xbf\xee\xa3\xac\xc6\xb1\xc3\xe6\xbc\x
# ...

# %%
s3=s2.encode('utf-8')
 
print('**************')
s3
# Out:
# **************
# ...

# %%
import csv
csvf = open(r'E:\python培训\年报爬取\连续天数的年报\stkcd.csv', 'r', encoding='utf-8', newline='')
writer = csv.reader(csvf)
 
for row in writer:
    print(row)
# Out:
# ['stkcd']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']
# ['600807']
# ['601519']

# %%
import csv
csvf = open(r'E:\python培训\年报爬取\连续天数的年报\aaa.csv', 'w', encoding='gbk', newline='')

# %%
writer = csv.writer(csvf)

# %%
line1 = ('张三', '25')
writer.writerow(line1)
# Out:
# 7

# %%
line1 = ('李四', '27')
writer.writerow(line1)
# Out:
# 7

# %%
csvf.close()
