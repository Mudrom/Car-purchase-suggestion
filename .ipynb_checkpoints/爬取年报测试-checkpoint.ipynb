# %%
# -*- coding: utf-8 -*-
import requests
import time
import random
import os
import json
import csv
import re
h1={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36'}
#下载pdf公告的函数
def downloadpdf(url,h,file,t):
    resp = requests.get(url,headers=h,stream=t)
    f = open(file, 'wb')
    f.write(resp.content)
    f.close()

# 定义爬取函数
def get_pdf_address(pageNum,start_date,end_date):
    url='http://www.szse.cn/api/disc/announcement/annList?random=%s'% random.random()
    headers={'Accept': 'application/json, text/javascript, */*; q=0.01'
    ,'Accept-Encoding': 'gzip, deflate'
    ,'Accept-Language': 'zh-CN,zh;q=0.9'
    ,'Connection': 'keep-alive'
    ,'Content-Length': '127'#
    ,'Content-Type': 'application/json'
    ,'Host': 'www.szse.cn'
    ,'Origin': 'http://www.szse.cn'
    ,'Referer': 'http://www.szse.cn/disclosure/listed/notice/index.html'
    ,'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36'
    ,'X-Request-Type': 'ajax'
    ,'X-Requested-With': 'XMLHttpRequest'}
    
    pagenum = int(pageNum)
    payload={'seDate': ["{}-01-01".format(start_date), "{}-02-26".format(end_date)] 
        ,'bigCategoryId': ["010301"]#
        ,'channelCode': ["listedNotice_disc"]
        ,'pageNum':pagenum
        ,'pageSize': '30'
        }
    r = requests.post(url,headers = headers,data = json.dumps(payload))
    result = r.json()
    return result

#新建csv文件，存储公告详细信息
csvf = open('E:\\python培训\\年报爬取\\深交所\\深圳证券市场公告.csv', 'w', encoding='gbk', newline='')
writer = csv.writer(csvf)
writer.writerow(('公司名', '股票代码', '发布时间'))
count = 0
url_head = 'http://disc.static.szse.cn/download/'
end = 2021
while end >2018:
    start = end-1 
    result = get_pdf_address(1,start,end)
    print("开始爬取{}-12-31至{}-12-31的年报".format(start,end))
    pages = int(result['announceCount']/30 + 1)+1
    print("共%s页" % pages)
    for i in range(1,pages):
        print("爬取深交所年报下载地址第{}页".format(i))
        result = get_pdf_address(i,start,end)
        num = len(result['data'])
        for each in range(num):
            code = result['data'][each]['secCode'][0]
            name = result['data'][each]['secName'][0]
            title=result['data'][each]['title']
            p_time = result['data'][each]['publishTime'].split(' ')[0]
            url_d=result['data'][each]['attachPath']
            if re.search('年度报告',title,re.S):
                if re.search('摘要',title,re.S):###避免下载一些年报摘要等不需要的文件###
                    pass
                elif re.search('半',title,re.S):###避免下载一些年报摘要等不需要的文件###:
                    pass
                else:
                    adjunctUrl ='http://disc.static.szse.cn/download/'+url_d
                    pdffile ='E://python培训/年报爬取/深交所/'+code+'-'+name+'-'+ p_time+'.pdf'
                    downloadpdf(url=adjunctUrl,h=h1, file=pdffile,t=True)
                    writer.writerow(( code, name,p_time))
                    print('获取完成')
                    print("========================================")
                    
                    time.sleep(random.random())
    end=end-1
# Out:
# 开始爬取2020-12-31至2021-12-31的年报
# 共168页
# 爬取深交所年报下载地址第1页
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19508/1250946572.py in <module>
#      73                     adjunctUrl ='http://disc.static.szse.cn/download/'+url_d
#      74                     pdffile ='E://python培训/年报爬取/深交所/'+code+'-'+ p_time+'.pdf'
# ---> 75                     downloadpdf(url=adjunctUrl,h=h1, file=pdffile,t=True)
#      76                     writer.writerow(( code, name,p_time))
#      77                     print('获取完成')
#
# ~\AppData\Local\Temp/ipykernel_19508/1250946572.py in downloadpdf(url, h, file, t)
#      12     resp = requests.get(url,headers=h,stream=t)
#      13     f = open(file, 'wb')
# ---> 14     f.write(resp.content)
#      15     f.close()
#      16
#
# h:\python39\lib\site-packages\requests\models.py in content(self)
#     834                 self._content = None
#     835             else:
# --> 836                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     837
#     838         self._content_consumed = True
#
# h:\python39\lib\site-packages\requests\models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# h:\python39\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# h:\python39\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# h:\python39\lib\http\client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# h:\python39\lib\http\client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# h:\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:
